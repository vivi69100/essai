# %% [markdown]
# <a href="https://colab.research.google.com/github/vivi69100/essai/blob/main/my_streamlit_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv")
data.head(1)
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0  14.0          8          350  165       4209          12  1972       US.

# %%
data.shape
# Out:
# (261, 8)

# %%
sns.heatmap(data.corr(), center = 0, cmap = "vlag", annot=True)
# Out:
# <ipython-input-22-a4ff62e8640f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), center = 0, cmap = "vlag", annot=True)
# <Axes: >

# %% [markdown]
# # "mpg" est négativement corrélé avec "cylinders", "cubicinches", "hp" et "weightlbs", ce qui signifie que plus ces valeurs augmentent, la consommation de carburant diminue.
# # "mpg" est positivement corrélé avec "time-to-60" et "year", indiquant une légère tendance à une meilleure consommation de carburant au fil du temps.

# %%
data.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
plt.boxplot(data['cylinders'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f60e2529660>,
#   <matplotlib.lines.Line2D at 0x7f60e2529900>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f60e2529ba0>,
#   <matplotlib.lines.Line2D at 0x7f60e2529e40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f60e25293c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f60e252a0e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f60e252a380>],
#  'means': []}

# %%
data['cylinders'].describe()
# Out:
# count    261.000000
# mean       5.590038
# std        1.733310
# min        3.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max        8.000000
# Name: cylinders, dtype: float64

# %%
data['weightlbs'].describe()
# Out:
# count     261.000000
# mean     3009.375479
# std       849.124991
# min      1613.000000
# 25%      2254.000000
# 50%      2900.000000
# 75%      3664.000000
# max      4997.000000
# Name: weightlbs, dtype: float64

# %% [markdown]
# la plupart de voiture pese environ 2000LBS

# %%
plt.figure(figsize= (12,5))
sns.lineplot(x=data['year'],y=data['weightlbs'])
# Out:
# <Axes: xlabel='year', ylabel='weightlbs'>

# %% [markdown]
# le poids a tendance de diminuer au fil du temps.
